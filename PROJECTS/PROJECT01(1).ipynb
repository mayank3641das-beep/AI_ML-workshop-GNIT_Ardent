# %%
# STUDENT INTRO GENERATOR

students = ["Prithvish", "Kaustav", "Prince", "Mayank"]

roles = ["The Creative Thinker", "The Tech Wizard", "The Social Connector", "The Data Maestro"]

hobbies = ["sketching and reading sci-fi", "competitive programming", "photography and football", "chess and watching tech documentaries"]

mottos = ["Think big, build bigger.", "Optimize everything.", "Teamwork makes the dream work.", "In data we trust."]

print("===== STUDENT INTRODUCTIONS =====")
print()

for i in range(4):
    print("Name   :", students[i])
    print("Role   :", roles[i])
    print("Hobby  :", hobbies[i])
    print("Motto  :", mottos[i])
    print("---------------------------------")
# Out:
# ===== STUDENT INTRODUCTIONS =====
#
# Name   : Prithvish
# Role   : The Creative Thinker
# Hobby  : sketching and reading sci-fi
# Motto  : Think big, build bigger.
# ---------------------------------
# Name   : Kaustav
# Role   : The Tech Wizard
# Hobby  : competitive programming
# Motto  : Optimize everything.
# ---------------------------------
# Name   : Prince
# Role   : The Social Connector
# Hobby  : photography and football
# Motto  : Teamwork makes the dream work.
# ---------------------------------
# Name   : Mayank
# Role   : The Data Maestro
# Hobby  : chess and watching tech documentaries
# Motto  : In data we trust.
# ---------------------------------
