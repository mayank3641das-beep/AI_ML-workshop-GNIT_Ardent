# %% [markdown]
# **SMART GRADE CALCULATOR**

# %%
# SMART GRADE CALCULATOR

name=input("enter student name:")

sub1=float(input("enter marks of sub1:"))
sub2=float(input("enter marks of sub2:"))
sub3=float(input("enter marks of sub3:"))
sub4=float(input("enter marks of sub4:"))
sub5=float(input("enter marks of sub5:"))

total=sub1+sub2+sub3+sub4+sub5
avg=total/5

if avg>=90:
  grade='A'
elif avg>=80:
  grade='B'
elif avg>=70:
  grade='C'
elif avg>=60:
  grade='D'
else:
  grade='F'

print("student name:",name)
print("total marks:",total)
print("average marks:",avg)
print("grade:",grade)
# Out:
# enter student name:prithvish
# enter marks of sub1:99
# enter marks of sub2:99
# enter marks of sub3:99
# enter marks of sub4:99
# enter marks of sub5:99
# student name: prithvish
# total marks: 495.0
# average marks: 99.0
# grade: A
