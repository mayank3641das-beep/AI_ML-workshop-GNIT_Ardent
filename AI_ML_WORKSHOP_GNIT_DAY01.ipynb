# %%
#Print your name, age and department
name = input("Enter your name ")
age = input("Enter your age ")
department = input("Enter your department")
print(f"my name is {name}, age is {age},& my department is {department}")
# Out:
# Enter your name Prithvish
# Enter your age 19
# Enter your departmentECE
# my name is Prithvish, age is 19,& my department is ECE

# %%
#take city as input and print it
city= input("enter your city")
print(city)
# Out:
# enter your cityKolkata
# Kolkata

# %%
#take two numbers and print their sums(hardcoded values)
a= 10
b= 20
print(f"sum of {a}and{b}={a+b}")
# Out:
# sum of 10and20=30

# %%
#take two numbers and print their sums(user input)
num1= int(input("enter first number:"))
num2= int(input("enter second number:"))

sum_result= num1 + num2
print(f"sum of {num1} and {num2}={sum_result}")
# Out:
# enter first number:67
# enter second number:41
# sum of 67 and 41=108

# %%
#take one float number and print it
num = float(input("enter float number"))
print(f"you entered:{num}")
# Out:
# enter float number67
# you entered:67.0

# %%
#create variables for name , salary and job role
name = input("enter your name")
salary = {float(input("enter your salary"))}
job_role = input("enter your job role")
print(f"my name is {name},salary is {salary},& my job role is {job_role}")
# Out:
# enter your namePrithvish
# enter your salary7000000000
# enter your job roledata scientist
# my name is Prithvish,salary is {7000000000.0},& my job role is data scientist

# %%
#print a welcome message
name = input("enter your name")
print(f"welcome, {name}!")
# Out:
# enter your nameBenjamin
# welcome, Benjamin!

# %%
#print my introduction(basic)
name = input("enter your name")
age= input("enter your age")
city= input("enter your city")
Occupation= input("enter your occupation")
# Out:
# enter your namePrithvish
# enter your age19
# enter your citykolkata
# enter your occupationstudent

# %%
#build a simple calculator
num1 = float(input("enter first number:"))
num2 = float(input("enter second number:"))
operation = input("enter operation(+,-,*,/):")

if operation == '+':
    result = num1 + num2
    print(str(num1) + "+" + str(num2) + "=" + str(result))
elif operation == '-':
    result = num1 - num2
    print(str(num1) + "-" + str(num2) + "=" + str(result))
elif operation == '*':
    result = num1 * num2
    print(str(num1) + "*" + str(num2) + "=" + str(result))
elif operation == '/':
    if num2 != 0:
        result = num1 / num2
        print(str(num1) + "/" + str(num2) + "=" + str(result))
    else:
        print("Error: Division by zero is not allowed.")
else:
    print("Invalid operation")
# Out:
# enter first number:67
# enter second number:78
# enter operation(+,-,*,/):+
# 67.0+78.0=145.0

# %%
#write a program to take marks input and print it(simple)

marks= float(input("enter your marks"))
print(f"your marks is {marks}")
# Out:
# enter your marks100
# your marks is 100.0

# %%
#create variables for 5 different data types
Var_int= 10
var_flaot=20.5
var_boolean= 'true'
var_linkedlist=[1,2,3,4]
var_string="hello"
print(Var_int)
print(var_flaot)
print(var_boolean)
print(var_linkedlist)
print(var_string)
# Out:
# 10
# 20.5
# true
# [1, 2, 3, 4]
# hello
